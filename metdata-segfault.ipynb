# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from glob import glob

import matplotlib.pyplot as plt
import cartopy.crs as ccrs

import numpy as np
import xarray as xr

# %%
inputdata = "/glade/p/cesmdata/cseg/inputdata"
badfile = f'{inputdata}/atm/cam/met/nudging/MERRA2_fv09_32L/1988/MERRA2_fv09.cam2.i.1988-04-02-75600.nc'

allfiles = sorted(glob(f'{inputdata}/atm/cam/met/nudging/MERRA2_fv09_32L/1988/*.nc'))
os.environ['FILE'] = badfile
ibad = allfiles.index(badfile)

# %%
# !echo ${FILE}
# Out:
# /glade/p/cesmdata/cseg/inputdata/atm/cam/met/nudging/MERRA2_fv09_32L/1988/MERRA2_fv09.cam2.i.1988-04-02-75600.nc

# %%
# !ncdump -h ${FILE}
# Out:
# netcdf MERRA2_fv09.cam2.i.1988-04-02-75600 {
# dimensions:
# 	lat = 192 ;
# 	lon = 288 ;
# 	slat = 191 ;
# 	slon = 288 ;
# 	lev = 32 ;
# 	ilev = 33 ;
# 	time = UNLIMITED ; // (1 currently)
# 	scalar = 1 ;
# 	ncl8 = 1 ;
# 	ncl9 = 1 ;
# 	ncl10 = 1 ;
# 	ncl11 = 1 ;
# variables:
# 	double time(time) ;
# 		time:long_name = "time" ;
# 		time:units = "days since base date (nbdate)" ;
# 		time:calendar = "noleap" ;
# 		time:_FillValue = 9.96920996838687e+36 ;
# 	int ndbase(scalar) ;
# 		ndbase:long_name = "base day" ;
# 	int nsbase(scalar) ;
# 		nsbase:long_name = "seconds of base day" ;
# 	int nbdate(scalar) ;
# 		nbdate:long_name = "base date (YYYYMMDD)" ;
# 	int nbsec(scalar) ;
# 		nbsec:long_name = "seconds of base date" ;
# 	int ndcur(time) ;
# 		ndcur:long_name = "current day (from base day)" ;
# 		ndcur:_FillValue = -2147483647 ;
# 	int nscur(time) ;
# 		nscur:long_name = "current seconds of current day" ;
# 	int date(time) ;
# 		date:long_name = "current date (YYYYMMDD)" ;
# 	int datesec(time) ;
# 		datesec:long_name = "current seconds of current date" ;
# 	double P0(scalar) ;
# 		P0:long_name = "reference pressure" ;
# 		P0:units = "Pa" ;
# 	double lev(lev) ;
# 		lev:long_name = "hybrid level at midpoints (1000*(A+B))" ;
# 		lev:units = "level" ;
# 		lev:positive = "down" ;
# 		lev:standard_name = "atmosphere_hybrid_sigma_pressure_coordinate" ;
# 		lev:formula_terms = "a: hyam b: hybm p0: P0 ps: PS" ;
# 		lev:source_file = "/glade/p/acom/acom-climate/tilmes/inputdata/init/cesm2/f.e21.FWSD.f09_f09_mg17.acclip.2019.001.cam.i.2019-01-01_32L.nc" ;
# 	double ilev(ilev) ;
# 		ilev:long_name = "hybrid level at interfaces (1000*(A+B))" ;
# 		ilev:units = "level" ;
# 		ilev:positive = "down" ;
# 		ilev:standard_name = "atmosphere_hybrid_sigma_pressure_coordinate" ;
# 		ilev:formula_terms = "a: hyai b: hybi p0: P0 ps: PS" ;
# 		ilev:source_file = "/glade/p/acom/acom-climate/tilmes/inputdata/init/cesm2/f.e21.FWSD.f09_f09_mg17.acclip.2019.001.cam.i.2019-01-01_32L.nc" ;
# 	double hyai(ilev) ;
# 		hyai:long_name = "hybrid A coefficient at layer interfaces" ;
# 		hyai:source_file = "/glade/p/acom/acom-climate/tilmes/inputdata/init/cesm2/f.e21.FWSD.f09_f09_mg17.acclip.2019.001.cam.i.2019-01-01_32L.nc" ;
# 	double hybi(ilev) ;
# 		hybi:long_name = "hybrid B coefficient at layer interfaces" ;
# 		hybi:source_file = "/glade/p/acom/acom-climate/tilmes/inputdata/init/cesm2/f.e21.FWSD.f09_f09_mg17.acclip.2019.001.cam.i.2019-01-01_32L.nc" ;
# 	double hyam(lev) ;
# 		hyam:long_name = "hybrid A coefficient at layer midpoints" ;
# 		hyam:source_file = "/glade/p/acom/acom-climate/tilmes/inputdata/init/cesm2/f.e21.FWSD.f09_f09_mg17.acclip.2019.001.cam.i.2019-01-01_32L.nc" ;
# 	double hybm(lev) ;
# 		hybm:long_name = "hybrid B coefficient at layer midpoints" ;
# 		hybm:source_file = "/glade/p/acom/acom-climate/tilmes/inputdata/init/cesm2/f.e21.FWSD.f09_f09_mg17.acclip.2019.001.cam.i.2019-01-01_32L.nc" ;
# 	double lat(lat) ;
# 		lat:long_name = "latitude" ;
# 		lat:units = "degrees_north" ;
# 	double lon(lon) ;
# 		lon:long_name = "longitude" ;
# 		lon:units = "degrees_east" ;
# 	double slat(slat) ;
# 		slat:long_name = "staggered latitude" ;
# 		slat:units = "degrees_north" ;
# 	double slon(slon) ;
# 		slon:long_name = "staggered longitude" ;
# 		slon:units = "degrees_east" ;
# 	double w_stag(slat) ;
# 		w_stag:long_name = "staggered latitude weights" ;
# 	int ntrm(scalar) ;
# 		ntrm:long_name = "spectral truncation parameter M" ;
# 	int ntrn(scalar) ;
# 		ntrn:long_name = "spectral truncation parameter N" ;
# 	int ntrk(scalar) ;
# 		ntrk:long_name = "spectral truncation parameter K" ;
# 	double gw(lat) ;
# 		gw:long_name = "gauss weights" ;
# 		gw:lat = -90. ;
# 	float U(time, lev, lat, lon) ;
# 		U:long_name = "Zonal wind" ;
# 		U:units = "m/s" ;
# 		U:source_file = "/glade/collections/rda/data/ds313.3/orig_res/1988/MERRA2_orig_res_19880402.nc" ;
# 		U:source_field_name = "U" ;
# 		U:horz_interp_flag = "binning" ;
# 		U:vert_interp_flag = "linear_logp_opt2" ;
# 	float V(time, lev, lat, lon) ;
# 		V:long_name = "Meridional wind" ;
# 		V:units = "m/s" ;
# 		V:source_file = "/glade/collections/rda/data/ds313.3/orig_res/1988/MERRA2_orig_res_19880402.nc" ;
# 		V:source_field_name = "V" ;
# 		V:horz_interp_flag = "binning" ;
# 		V:vert_interp_flag = "linear_logp_opt2" ;
# 	float US(time, lev, slat, lon) ;
# 		US:long_name = "Zonal wind, staggered" ;
# 		US:units = "m/s" ;
# 		US:source_file = "/glade/collections/rda/data/ds313.3/orig_res/1988/MERRA2_orig_res_19880402.nc" ;
# 		US:source_field_name = "U" ;
# 		US:horz_interp_flag = "binning" ;
# 		US:vert_interp_flag = "linear_logp_opt2" ;
# 	float VS(time, lev, lat, slon) ;
# 		VS:long_name = "Meridional wind, staggered" ;
# 		VS:units = "m/s" ;
# 		VS:source_file = "/glade/collections/rda/data/ds313.3/orig_res/1988/MERRA2_orig_res_19880402.nc" ;
# 		VS:source_field_name = "V" ;
# 		VS:horz_interp_flag = "binning" ;
# 		VS:vert_interp_flag = "linear_logp_opt2" ;
# 	float T(time, lev, lat, lon) ;
# 		T:long_name = "Temperature" ;
# 		T:units = "K" ;
# 		T:source_file = "/glade/collections/rda/data/ds313.3/orig_res/1988/MERRA2_orig_res_19880402.nc" ;
# 		T:source_field_name = "T" ;
# 		T:horz_interp_flag = "binning" ;
# 		T:vert_interp_flag = "quad_logp_opt1" ;
# 	float Q(time, lev, lat, lon) ;
# 		Q:long_name = "Specific humidity" ;
# 		Q:units = "kg/kg" ;
# 		Q:source_file = "/glade/collections/rda/data/ds313.3/orig_res/1988/MERRA2_orig_res_19880402.nc" ;
# 		Q:source_field_name = "Q" ;
# 		Q:horz_interp_flag = "binning" ;
# 		Q:vert_interp_flag = "linear_opt1" ;
# 	float PS(time, lat, lon) ;
# 		PS:long_name = "Surface pressure" ;
# 		PS:units = "Pa" ;
# 		PS:source_file = "/glade/collections/rda/data/ds313.3/orig_res/1988/MERRA2_orig_res_19880402.nc" ;
# 		PS:source_field_name = "PS" ;
# 		PS:horz_interp_flag = "binning" ;
# 	float PHIS(time, lat, lon) ;
# 		PHIS:long_name = "Surface geopotential" ;
# 		PHIS:units = "m2/s2" ;
# 		PHIS:source_file = "/glade/p/cesmdata/cseg/inputdata/atm/cam/topo/fv_0.9x1.25_nc3000_Nsw042_Nrs008_Co060_Fi001_ZR_sgh30_24km_GRNL_c170103.nc" ;
# 		PHIS:source_field_name = "PHIS" ;
# 		PHIS:horz_interp_flag = "no_interp" ;
#
# // global attributes:
# 		:Conventions = "NCAR-CSM" ;
# 		:Description = "Re-gridded CAM Initial Conditions from the following source(s):" ;
# 		:source1 = "/glade/collections/rda/data/ds313.3/orig_res/1988/MERRA2_orig_res_19880402.nc" ;
# 		:source2 = "/glade/collections/rda/data/ds313.3/orig_res/1988/MERRA2_orig_res_19880402.nc" ;
# 		:source3 = "/glade/p/cesmdata/cseg/inputdata/atm/cam/topo/fv_0.9x1.25_nc3000_Nsw042_Nrs008_Co060_Fi001_ZR_sgh30_24km_GRNL_c170103.nc" ;
# 		:source_lev_info = "/glade/p/acom/acom-climate/tilmes/inputdata/init/cesm2/f.e21.FWSD.f09_f09_mg17.acclip.2019.001.cam.i.2019-01-01_32L.nc" ;
# 		:hybrid_sigma_pressure = "p(i,j,k) = A(k)*PO + B(k)*PS(i,j)" ;
# 		:logname = "tilmes" ;
# 		:host = "r9i6n14" ;
# 		:hosttype = "x86_64-linux" ;
# 		:Command = "NCL script" ;
# 		:Date_Written = "Fri Mar 18 13:46:15 MDT 2022" ;
# 		:case = "MERRA2_fv09" ;
# 		:ps_adjust = "True; Adjust Ps per ECMWF algorithm" ;
# 		:q_adjust = "True; Eliminate super-saturation" ;
# 		:interp_log_ps = "True; Interpolate ln(Ps) rather than Ps" ;
# }

# %%
ds_good = xr.open_dataset(allfiles[ibad-1], decode_times=False)
ds_good
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, scalar: 1, lev: 32, ilev: 33, lat: 192, lon: 288, slat: 191, slon: 288)
# Coordinates:
#   * time     (time) float64 0.75
#   * lev      (lev) float64 3.643 7.595 14.36 24.61 ... 936.2 957.5 976.3 992.6
#   * ilev     (ilev) float64 2.255 5.032 10.16 18.56 ... 947.4 967.5 985.1 1e+03
#   * lat      (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * slat     (slat) float64 -89.53 -88.59 -87.64 -86.7 ... 87.64 88.59 89.53
#   * slon     (slon) float64 -0.625 0.625 1.875 3.125 ... 354.4 355.6 356.9 358.1
# Dimensions without coordinates: scalar
# Data variables: (12/26)
#     ndbase   (scalar) int32 ...
#     nsbase   (scalar) int32 ...
#     nbdate   (scalar) int32 ...
#     nbsec    (scalar) int32 ...
#     ndcur    (time) float64 ...
#     nscur    (time) int32 ...
#     ...       ...
#     US       (time, lev, slat, lon) float32 ...
#     VS       (time, lev, lat, slon) float32 ...
#     T        (time, lev, lat, lon) float32 ...
#     Q        (time, lev, lat, lon) float32 ...
#     PS       (time, lat, lon) float32 ...
#     PHIS     (time, lat, lon) float32 ...
# Attributes: (12/16)
#     Conventions:            NCAR-CSM
#     Description:            Re-gridded CAM Initial Conditions from the follow...
#     source1:                /glade/collections/rda/data/ds313.3/orig_res/1988...
#     source2:                /glade/collections/rda/data/ds313.3/orig_res/1988...
#     source3:                /glade/p/cesmdata/cseg/inputdata/atm/cam/topo/fv_...
#     source_lev_info:        /glade/p/acom/acom-climate/tilmes/inputdata/init/...
#     ...                     ...
#     Command:                NCL script
#     Date_Written:           Fri Mar 18 13:46:00 MDT 2022
#     case:                   MERRA2_fv09
#     ps_adjust:              True; Adjust Ps per ECMWF algorithm
#     q_adjust:               True; Eliminate super-saturation
#     interp_log_ps:          True; Interpolate ln(Ps) rather than Ps

# %%
ds_bad = xr.open_dataset(allfiles[ibad], decode_times=False)
ds_bad
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, scalar: 1, lev: 32, ilev: 33, lat: 192, lon: 288, slat: 191, slon: 288)
# Coordinates:
#   * time     (time) float64 0.875
#   * lev      (lev) float64 3.643 7.595 14.36 24.61 ... 936.2 957.5 976.3 992.6
#   * ilev     (ilev) float64 2.255 5.032 10.16 18.56 ... 947.4 967.5 985.1 1e+03
#   * lat      (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
#   * slat     (slat) float64 -89.53 -88.59 -87.64 -86.7 ... 87.64 88.59 89.53
#   * slon     (slon) float64 -0.625 0.625 1.875 3.125 ... 354.4 355.6 356.9 358.1
# Dimensions without coordinates: scalar
# Data variables: (12/26)
#     ndbase   (scalar) int32 ...
#     nsbase   (scalar) int32 ...
#     nbdate   (scalar) int32 ...
#     nbsec    (scalar) int32 ...
#     ndcur    (time) float64 ...
#     nscur    (time) int32 ...
#     ...       ...
#     US       (time, lev, slat, lon) float32 ...
#     VS       (time, lev, lat, slon) float32 ...
#     T        (time, lev, lat, lon) float32 ...
#     Q        (time, lev, lat, lon) float32 ...
#     PS       (time, lat, lon) float32 ...
#     PHIS     (time, lat, lon) float32 ...
# Attributes: (12/16)
#     Conventions:            NCAR-CSM
#     Description:            Re-gridded CAM Initial Conditions from the follow...
#     source1:                /glade/collections/rda/data/ds313.3/orig_res/1988...
#     source2:                /glade/collections/rda/data/ds313.3/orig_res/1988...
#     source3:                /glade/p/cesmdata/cseg/inputdata/atm/cam/topo/fv_...
#     source_lev_info:        /glade/p/acom/acom-climate/tilmes/inputdata/init/...
#     ...                     ...
#     Command:                NCL script
#     Date_Written:           Fri Mar 18 13:46:15 MDT 2022
#     case:                   MERRA2_fv09
#     ps_adjust:              True; Adjust Ps per ECMWF algorithm
#     q_adjust:               True; Eliminate super-saturation
#     interp_log_ps:          True; Interpolate ln(Ps) rather than Ps

# %%
ds_good.Q.isel(lev=-1).plot()

# %%
for v in ['T', 'Q', 'U', 'V']:
    print(v)
    
    print((ds_bad[v] == ds_bad[v][0, 0, 0, 0].values).all())
# Out:
# T
# <xarray.DataArray 'T' ()>
# array(False)
# Q
# <xarray.DataArray 'Q' ()>
# array(False)
# U
# <xarray.DataArray 'U' ()>
# array(False)
# V
# <xarray.DataArray 'V' ()>
# array(False)

# %%
ds_bad.V[0, 0, 0, 0].values
# Out:
# array(15.7733345, dtype=float32)
