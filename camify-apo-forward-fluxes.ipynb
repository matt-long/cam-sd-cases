# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from glob import glob
import yaml
import numpy as np
import xarray as xr
import warnings

import regrid_tools
import cesm_tools

# %%
dst_grid = regrid_tools.grid('f09', grid_file='data/rectilinear_f09_SCRIP_20180107.nc')
dst_grid
# Out:
# grid: f09
# dims: (192, 288)
# file: data/rectilinear_f09_SCRIP_20180107.nc

# %%
src_grid = regrid_tools.grid('latlon', nx=360, ny=180, lon0=-180)
src_grid
# Out:
# exists: /glade/scratch/mclong/tmp/regridding/latlon_1.0x1.0_lon0=-180.0.nc
# grid: latlon_latlon_1.0x1.0_lon0=-180.0
# dims: (180, 360)
# file: /glade/scratch/mclong/tmp/regridding/latlon_1.0x1.0_lon0=-180.0.nc

# %%
regrid_obj = regrid_tools.regridder(src_grid, dst_grid, method='conserve', clobber=True)
regrid_obj
# Out:
# generating: /glade/scratch/mclong/tmp/regridding/latlon_latlon_1.0x1.0_lon0=-180.0_to_f09_conserve_extrap-none.nc
#  Starting weight generation with these inputs:
#    Source File: /glade/scratch/mclong/tmp/regridding/latlon_1.0x1.0_lon0=-180.0.nc
#    Destination File: data/rectilinear_f09_SCRIP_20180107.nc
#    Weight File: /glade/scratch/mclong/tmp/regridding/latlon_latlon_1.0x1.0_lon0=-180.0_to_f09_conserve_extrap-none.nc
#    Source File is in SCRIP format
#    Source Grid is a global grid
#    Source Grid is a logically rectangular grid
#    Use the center coordinates of the source grid to do the regrid
#    Destination File is in SCRIP format
#    Destination Grid is a global grid
#    Destination Grid is a logically rectangular grid
#    Use the center coordinates of the destination grid to do the regrid
#    Regrid Method: conserve
#    Pole option: NONE
#    Ignore unmapped destination points
#    Output weight file in NetCDF4 file format
#    Line Type: greatcircle
#    Norm Type: dstarea
#    Extrap. Method: none
#
#  Completed weight generation successfully.
#
#
# source grid dims: (180, 360)
# destination grid dims: (192, 288)
# regridder latlon_1.0x1.0_lon0=-180.0.nc --> rectilinear_f09_SCRIP_20180107.nc

# %%
with xr.open_dataset('data/cam_grid.0.9x1.25.nc') as grid_coords:
    grid_coords['area'] = cesm_tools.get_area(grid_coords, 'atm') 
    grid_coords = grid_coords.drop([v for v in grid_coords.variables if v not in ['lat', 'lon', 'area']])
grid_coords
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 192, lon: 288)
# Coordinates:
#   * lat      (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 87.17 88.12 89.06 90.0
#   * lon      (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
# Data variables:
#     area     (lat, lon) float64 2.995e+07 2.995e+07 ... 2.995e+07 2.995e+07
# Attributes:
#     Conventions:       CF-1.0
#     source:            CAM
#     case:              cam6327_sd.apo_test_srf_emis.002
#     logname:           mclong
#     host:              cheyenne4
#     initial_file:      /glade/work/mclong/cam-sd-cases/data/f.e20.FWAMIP.f09_...
#     topography_file:   /glade/work/tilmes/inputdata/topo/fv_0.9x1.25_nc3000_N...
#     model_doi_url:     https://doi.org/10.5065/D67H1H0V
#     time_period_freq:  hour_6

# %%
clobber = True

flux_product_dir = "/glade/work/mclong/sno-analysis/sno-flux-products"
flux_product_camified = f"{flux_product_dir}-camified"
os.makedirs(flux_product_camified, exist_ok=True)

srf_emis_files_raw = {
    "apo_jena": f"{flux_product_dir}/SFAPO_OCN.carboscope.apo99X_v2021.1x1.19860101-20201231.nc",
    "co2_gridfed": f"{flux_product_dir}/SFCO2_FF.GCP-GridFED.v2021.3.1x1.19860101-20201231.nc",
    "co2_oco2mip": f"{flux_product_dir}/SFCO2_FF.OCO2-MIP.v2020.1.1x1.19860101-20201231.nc",
    "co2_cesm": f"{flux_product_dir}/SFCO2_OCN.cesm_fosi_smyle.1x1.19860101-20201231.nc",
    "co2_somffn": f"{flux_product_dir}/SFCO2_OCN.MPI-SOM-FFN.1x1.19860101-20201231.nc",
    "n2_cesm": f"{flux_product_dir}/SFN2_OCN.cesm_fosi_smyle.1x1.19860101-20201231.nc",
    "n2_era": f"{flux_product_dir}/SFN2_OCN.era5_shf.1x1.19860101-20201231.nc",
    "o2_gridfed": f"{flux_product_dir}/SFO2_FF.GCP-GridFED.v2021.3.1x1.19860101-20201231.nc",
    "o2_cesm": f"{flux_product_dir}/SFO2_OCN.cesm_fosi_smyle.1x1.19860101-20201231.nc",
    "o2_gk01r16": f"{flux_product_dir}/SFO2_OCN.gk2001_R2016.1x1.repeat_monclim.19860101-20201231.nc",
}

srf_emis_files_camified = {}
for v, path in srf_emis_files_raw.items():
    file_out = f"{flux_product_camified}/{os.path.basename(path)}".replace(
        ".1x1.", ".0.9x1.25."
    )

    flux_variable = os.path.basename(path).split(".")[0]
    constituent = flux_variable[2:].split("_")[0]
    constituent = "O2" if constituent == "APO" else constituent

    srf_emis_files_camified[v] = dict(
        flux_file=file_out,
        constituent=constituent,
        flux_variable=flux_variable,
    )
    if not os.path.exists(file_out) or clobber:

        with xr.open_dataset(path) as ds:
            year = ds.time_components[:, 0].astype(np.int32)
            month = ds.time_components[:, 1].astype(np.int32)
            day = ds.time_components[:, 2].astype(np.int32)

        # print(ds.time.values[0:5])
        # break
        ds["date"] = year * 10000 + month * 100 + day
        ds.date.attrs["units"] = "YYYYMMDD"
        ds.date.attrs["long_name"] = "Date"

        flux_var = [
            v for v, da in ds.data_vars.items() if da.dims == ("time", "lat", "lon")
        ]
        assert len(flux_var) == 1
        flux_var = flux_var[0]
        assert ds[flux_var].attrs["units"] == "mol/m^2/s"
        with xr.set_options(keep_attrs=True):
            ds[flux_var] = (
                ds[flux_var] * cesm_tools.molecules_per_mol * cesm_tools.m2_per_cm2
            )
            ds[flux_var].attrs["units"] = "molecules/cm2/s"

        ds_f09 = xr.merge(
            (
                ds[[v for v in ds.data_vars if ds[v].dims[-2:] != ("lat", "lon")]],
                grid_coords,
            )
        )
        ds_f09[flux_var] = regrid_obj(ds[flux_var])

        cesm_tools.to_netcdf_clean(ds_f09, file_out)
        cesm_tools.ncks_fl_fmt64bit(file_out)


srf_emis_files_camified
# Out:
# ------------------------------
# Writing /glade/work/mclong/sno-analysis/sno-flux-products-camified/SFAPO_OCN.carboscope.apo99X_v2021.0.9x1.25.19860101-20201231.nc
# netcdf SFAPO_OCN.carboscope.apo99X_v2021.0.9x1.25.19860101-20201231 {
# dimensions:
# 	lat = 192 ;
# 	lon = 288 ;
# 	time = 12784 ;
# 	d2 = 2 ;
# 	n_time_components = 6 ;
# variables:
# 	double lat(lat) ;
# 	double lon(lon) ;
# 	double time_bnds(time, d2) ;
# 		time_bnds:_FillValue = 9.96920996838687e+36 ;
# 	float time_components(time, n_time_components) ;
# 		time_components:_FillValue = 9.96921e+36f ;
# 		time_components:long_name = "time components (year, month, day, hour, min, sec)" ;
# 		time_components:units = "none" ;
# 	int date(time) ;
# 		date:_FillValue = -2147483647 ;
# 		date:units = "YYYYMMDD" ;
# 		date:long_name = "Date" ;
# 	double time(time) ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1986-01-01" ;
# 		time:calendar = "gregorian" ;
# 	float area(lat, lon) ;
# 		area:_FillValue = 9.96921e+36f ;
# 		area:units = "m2" ;
# 	float SFAPO_OCN(time, lat, lon) ;
# 		SFAPO_OCN:_FillValue = 9.96921e+36f ;
# 		SFAPO_OCN:long_name = "Ocean-atmosphere apo flux" ;
# 		SFAPO_OCN:units = "molecules/cm2/s" ;
# 		SFAPO_OCN:cell_methods = "lon: lat: sum" ;
#
# // global attributes:
# 		:history = "Tue Feb 22 13:22:20 2022: ncks -O --fl_fmt=64bit /glade/scratch/mclong/sno-flux-products/SFAPO_OCN.carboscope.apo99X_v2021.1x1.19860101-20201231.nc /glade/scratch/mclong/sno-flux-products/SFAPO_OCN.carboscope.apo99X_v2021.1x1.19860101-20201231.nc\nInversion code by Christian Roedenbeck; created by https://github.com/matt-long/sno-analysis/tree/bfdb4e7 on 2022-02-22; created by https://github.com/matt-long/sno-analysis/tree/ca4f18c on 2022-02-22" ;
# 		:title = "Jena CarboScope results" ;
# 		:institution = "MPI Biogeochemistry Jena" ;
# 		:references = "http://www.BGC-Jena.mpg.de/CarboScope/" ;
# 		:NCO = "netCDF Operators version 4.9.5 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)" ;
# }
# format: netCDF-4
# ------------------------------
# ------------------------------
# Writing /glade/work/mclong/sno-analysis/sno-flux-products-camified/SFCO2_FF.GCP-GridFED.v2021.3.0.9x1.25.19860101-20201231.nc
# netcdf SFCO2_FF.GCP-GridFED.v2021.3.0.9x1.25.19860101-20201231 {
# dimensions:
# 	lat = 192 ;
# 	lon = 288 ;
# 	time = 12784 ;
# 	d2 = 2 ;
# 	n_time_components = 6 ;
# variables:
# 	double lat(lat) ;
# 	double lon(lon) ;
# 	double time_bnds(time, d2) ;
# 		time_bnds:_FillValue = 9.96920996838687e+36 ;
# 	float time_components(time, n_time_components) ;
# 		time_components:_FillValue = 9.96921e+36f ;
# 		time_components:long_name = "time components (year, month, day, hour, min, sec)" ;
# 		time_components:units = "none" ;
# 	int date(time) ;
# 		date:_FillValue = -2147483647 ;
# 		date:units = "YYYYMMDD" ;
# 		date:long_name = "Date" ;
# 	double time(time) ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1986-01-01" ;
# 		time:calendar = "gregorian" ;
# 	float area(lat, lon) ;
# 		area:_FillValue = 9.96921e+36f ;
# 		area:units = "m2" ;
# 	float SFCO2_FF(time, lat, lon) ;
# 		SFCO2_FF:_FillValue = 9.96921e+36f ;
# 		SFCO2_FF:units = "molecules/cm2/s" ;
# 		SFCO2_FF:long_name = "Total CO2 emissions from: OIL, GAS, COAL, CEMENT, BUNKER" ;
#
# // global attributes:
# 		:description = "Emissions of CO2 from fossil fuel sources on a 0.1 x 0.1 grid. EDGAR v4.3.2 annual emissions are scaled at the national level to GCP emissions and subsequently amalgamated in this dataset." ;
# 		:history = "Tue Feb 22 13:20:34 2022: ncks -O --fl_fmt=64bit /glade/scratch/mclong/sno-flux-products/SFCO2_FF.GCP-GridFED.v2021.3.1x1.19860101-20201231.nc /glade/scratch/mclong/sno-flux-products/SFCO2_FF.GCP-GridFED.v2021.3.1x1.19860101-20201231.nc\nCreated by Matt Jones (UEA) on 2022-02-02; aggegrated and regridded to 1x1 by Matt Long (NCAR); created by https://github.com/matt-long/sno-analysis/tree/bfdb4e7 on 2022-02-22; created by https://github.com/matt-long/sno-analysis/tree/514728f on 2022-02-22" ;
# 		:source = "https://zenodo.org/record/5956612" ;
# 		:NCO = "netCDF Operators version 4.9.5 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)" ;
# }
# format: netCDF-4
# ------------------------------
# ------------------------------
# Writing /glade/work/mclong/sno-analysis/sno-flux-products-camified/SFCO2_FF.OCO2-MIP.v2020.1.0.9x1.25.19860101-20201231.nc
# netcdf SFCO2_FF.OCO2-MIP.v2020.1.0.9x1.25.19860101-20201231 {
# dimensions:
# 	lat = 192 ;
# 	lon = 288 ;
# 	time = 12784 ;
# 	d2 = 2 ;
# 	n_time_components = 6 ;
# variables:
# 	double lat(lat) ;
# 	double lon(lon) ;
# 	double time_bnds(time, d2) ;
# 		time_bnds:_FillValue = 9.96920996838687e+36 ;
# 	float time_components(time, n_time_components) ;
# 		time_components:_FillValue = 9.96921e+36f ;
# 		time_components:long_name = "time components (year, month, day, hour, min, sec)" ;
# 		time_components:units = "none" ;
# 	int date(time) ;
# 		date:_FillValue = -2147483647 ;
# 		date:units = "YYYYMMDD" ;
# 		date:long_name = "Date" ;
# 	double time(time) ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1986-01-01" ;
# 		time:calendar = "gregorian" ;
# 	float area(lat, lon) ;
# 		area:_FillValue = 9.96921e+36f ;
# 		area:units = "m2" ;
# 	float SFCO2_FF(time, lat, lon) ;
# 		SFCO2_FF:_FillValue = 9.96921e+36f ;
# 		SFCO2_FF:comment = "ODIAC fossil fuel flux convolved with TIMES emission factors" ;
# 		SFCO2_FF:authors = "ODIAC from Tomohiro Oda (tom.oda@nasa.gov), TIMES from Ray Nassar (ray.nassar@canada.ca), convolved by Sourish Basu (sourish.basu@noaa.gov)" ;
# 		SFCO2_FF:long_name = "Fossil fuel flux" ;
# 		SFCO2_FF:units = "molecules/cm2/s" ;
# 		SFCO2_FF:cell_methods = "time: sum" ;
#
# // global attributes:
# 		:description = "daily integral of Fossil Fuel CO2 Emissions for the OCO2 Model Intercomparison Project (MIP)" ;
# 		:source = "https://zenodo.org/record/4776925" ;
# 		:authors = "Basu, Sourish;  Nassar, Ray" ;
# 		:note = "daily integration and compilation by Matt Long (NCAR)" ;
# 		:history = "Tue Feb 22 13:21:05 2022: ncks -O --fl_fmt=64bit /glade/scratch/mclong/sno-flux-products/SFCO2_FF.OCO2-MIP.v2020.1.1x1.19860101-20201231.nc /glade/scratch/mclong/sno-flux-products/SFCO2_FF.OCO2-MIP.v2020.1.1x1.19860101-20201231.nc\ncreated by https://github.com/matt-long/sno-analysis/tree/1106d8f on 2022-02-15; created by https://github.com/matt-long/sno-analysis/tree/514728f on 2022-02-22" ;
# 		:NCO = "netCDF Operators version 4.9.5 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)" ;
# }
# format: netCDF-4
# ------------------------------
# ------------------------------
# Writing /glade/work/mclong/sno-analysis/sno-flux-products-camified/SFCO2_OCN.cesm_fosi_smyle.0.9x1.25.19860101-20201231.nc
# netcdf SFCO2_OCN.cesm_fosi_smyle.0.9x1.25.19860101-20201231 {
# dimensions:
# 	lat = 192 ;
# 	lon = 288 ;
# 	time = 12784 ;
# 	d2 = 2 ;
# 	n_time_components = 6 ;
# variables:
# 	double lat(lat) ;
# 	double lon(lon) ;
# 	double time_bnds(time, d2) ;
# 		time_bnds:_FillValue = 9.96920996838687e+36 ;
# 	float time_components(time, n_time_components) ;
# 		time_components:_FillValue = 9.96921e+36f ;
# 		time_components:long_name = "time components (year, month, day, hour, min, sec)" ;
# 		time_components:units = "none" ;
# 	int date(time) ;
# 		date:_FillValue = -2147483647 ;
# 		date:units = "YYYYMMDD" ;
# 		date:long_name = "Date" ;
# 	double time(time) ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1986-01-01" ;
# 		time:calendar = "gregorian" ;
# 	float area(lat, lon) ;
# 		area:_FillValue = 9.96921e+36f ;
# 		area:units = "m2" ;
# 	float SFCO2_OCN(time, lat, lon) ;
# 		SFCO2_OCN:_FillValue = 9.96921e+36f ;
# 		SFCO2_OCN:long_name = "DIC Surface Gas Flux" ;
# 		SFCO2_OCN:units = "molecules/cm2/s" ;
#
# // global attributes:
# 		:model_doi_url = "https://doi.org/10.5065/D67H1H0V" ;
# 		:source = "g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005" ;
# 		:note = "Leap day values are linearly interpolated from adjacent data" ;
# 		:history = "Tue Feb 22 13:21:50 2022: ncks -O --fl_fmt=64bit /glade/scratch/mclong/sno-flux-products/SFCO2_OCN.cesm_fosi_smyle.1x1.19860101-20201231.nc /glade/scratch/mclong/sno-flux-products/SFCO2_OCN.cesm_fosi_smyle.1x1.19860101-20201231.nc\ncreated by https://github.com/matt-long/sno-analysis/tree/3ae2e40 on 2022-02-15; created by https://github.com/matt-long/sno-analysis/tree/514728f on 2022-02-22" ;
# 		:NCO = "netCDF Operators version 4.9.5 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)" ;
# }
# format: netCDF-4
# ------------------------------
# ------------------------------
# Writing /glade/work/mclong/sno-analysis/sno-flux-products-camified/SFCO2_OCN.MPI-SOM-FFN.0.9x1.25.19860101-20201231.nc
# netcdf SFCO2_OCN.MPI-SOM-FFN.0.9x1.25.19860101-20201231 {
# dimensions:
# 	lat = 192 ;
# 	lon = 288 ;
# 	time = 12784 ;
# 	d2 = 2 ;
# 	n_time_components = 6 ;
# variables:
# 	double lat(lat) ;
# 	double lon(lon) ;
# 	double time_bnds(time, d2) ;
# 		time_bnds:_FillValue = 9.96920996838687e+36 ;
# 	float time_components(time, n_time_components) ;
# 		time_components:_FillValue = 9.96921e+36f ;
# 		time_components:long_name = "time components (year, month, day, hour, min, sec)" ;
# 		time_components:units = "none" ;
# 	int date(time) ;
# 		date:_FillValue = -2147483647 ;
# 		date:units = "YYYYMMDD" ;
# 		date:long_name = "Date" ;
# 	double time(time) ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1986-01-01" ;
# 		time:calendar = "gregorian" ;
# 	float area(lat, lon) ;
# 		area:_FillValue = 9.96921e+36f ;
# 		area:units = "m2" ;
# 	float SFCO2_OCN(time, lat, lon) ;
# 		SFCO2_OCN:_FillValue = 9.96921e+36f ;
# 		SFCO2_OCN:long_name = "CO2 flux smoothed" ;
# 		SFCO2_OCN:units = "molecules/cm2/s" ;
#
# // global attributes:
# 		:source = "MPI-SOM-FFN.v2021 CO2 fluxes" ;
# 		:history = "Tue Feb 22 13:22:12 2022: ncks -O --fl_fmt=64bit /glade/scratch/mclong/sno-flux-products/SFCO2_OCN.MPI-SOM-FFN.1x1.19860101-20201231.nc /glade/scratch/mclong/sno-flux-products/SFCO2_OCN.MPI-SOM-FFN.1x1.19860101-20201231.nc\ncreated by https://github.com/matt-long/sno-analysis/tree/50ea711 on 2022-02-15; created by https://github.com/matt-long/sno-analysis/tree/514728f on 2022-02-22" ;
# 		:NCO = "netCDF Operators version 4.9.5 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)" ;
# }
# format: netCDF-4
# ------------------------------
# ------------------------------
# Writing /glade/work/mclong/sno-analysis/sno-flux-products-camified/SFN2_OCN.cesm_fosi_smyle.0.9x1.25.19860101-20201231.nc
# netcdf SFN2_OCN.cesm_fosi_smyle.0.9x1.25.19860101-20201231 {
# dimensions:
# 	lat = 192 ;
# 	lon = 288 ;
# 	time = 12784 ;
# 	d2 = 2 ;
# 	n_time_components = 6 ;
# variables:
# 	double lat(lat) ;
# 	double lon(lon) ;
# 	double time_bnds(time, d2) ;
# 		time_bnds:_FillValue = 9.96920996838687e+36 ;
# 	float time_components(time, n_time_components) ;
# 		time_components:_FillValue = 9.96921e+36f ;
# 		time_components:long_name = "time components (year, month, day, hour, min, sec)" ;
# 		time_components:units = "none" ;
# 	int date(time) ;
# 		date:_FillValue = -2147483647 ;
# 		date:units = "YYYYMMDD" ;
# 		date:long_name = "Date" ;
# 	double time(time) ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1986-01-01" ;
# 		time:calendar = "gregorian" ;
# 	float area(lat, lon) ;
# 		area:_FillValue = 9.96921e+36f ;
# 		area:units = "m2" ;
# 	float SFN2_OCN(time, lat, lon) ;
# 		SFN2_OCN:_FillValue = 9.96921e+36f ;
# 		SFN2_OCN:units = "molecules/cm2/s" ;
# 		SFN2_OCN:long_name = "N2 air-sea flux (computed from heat flux)" ;
# 		SFN2_OCN:note = "fluxes computed using F = c * (-dC/dT) * Q/Cp; c = 0.7692" ;
#
# // global attributes:
# 		:model_doi_url = "https://doi.org/10.5065/D67H1H0V" ;
# 		:source = "g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005" ;
# 		:note = "Leap day values are linearly interpolated from adjacent data" ;
# 		:history = "Tue Feb 22 13:21:27 2022: ncks -O --fl_fmt=64bit /glade/scratch/mclong/sno-flux-products/SFN2_OCN.cesm_fosi_smyle.1x1.19860101-20201231.nc /glade/scratch/mclong/sno-flux-products/SFN2_OCN.cesm_fosi_smyle.1x1.19860101-20201231.nc\ncreated by https://github.com/matt-long/sno-analysis/tree/3ae2e40 on 2022-02-15; created by https://github.com/matt-long/sno-analysis/tree/514728f on 2022-02-22" ;
# 		:NCO = "netCDF Operators version 4.9.5 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)" ;
# }
# format: netCDF-4
# ------------------------------
# ------------------------------
# Writing /glade/work/mclong/sno-analysis/sno-flux-products-camified/SFN2_OCN.era5_shf.0.9x1.25.19860101-20201231.nc
# netcdf SFN2_OCN.era5_shf.0.9x1.25.19860101-20201231 {
# dimensions:
# 	lat = 192 ;
# 	lon = 288 ;
# 	time = 12784 ;
# 	d2 = 2 ;
# 	n_time_components = 6 ;
# variables:
# 	double lat(lat) ;
# 	double lon(lon) ;
# 	double time_bnds(time, d2) ;
# 		time_bnds:_FillValue = 9.96920996838687e+36 ;
# 	float time_components(time, n_time_components) ;
# 		time_components:_FillValue = 9.96921e+36f ;
# 		time_components:long_name = "time components (year, month, day, hour, min, sec)" ;
# 		time_components:units = "none" ;
# 	int date(time) ;
# 		date:_FillValue = -2147483647 ;
# 		date:units = "YYYYMMDD" ;
# 		date:long_name = "Date" ;
# 	double time(time) ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1986-01-01" ;
# 		time:calendar = "gregorian" ;
# 	float area(lat, lon) ;
# 		area:_FillValue = 9.96921e+36f ;
# 		area:units = "m2" ;
# 	float SFN2_OCN(time, lat, lon) ;
# 		SFN2_OCN:_FillValue = 9.96921e+36f ;
# 		SFN2_OCN:units = "molecules/cm2/s" ;
# 		SFN2_OCN:long_name = "N2 air-sea flux (computed from heat flux)" ;
# 		SFN2_OCN:note = "fluxes computed using F = c * (-dC/dT) * Q/Cp; c = 0.7692" ;
#
# // global attributes:
# 		:note = "Heat flux from ERA5 Reanalysis: https://cds.climate.copernicus.eu/cdsapp#!/dataset/reanalysis-era5-single-levels-monthly-means" ;
# 		:history = "Tue Feb 22 13:20:11 2022: ncks -O --fl_fmt=64bit /glade/scratch/mclong/sno-flux-products/SFN2_OCN.era5_shf.1x1.19860101-20201231.nc /glade/scratch/mclong/sno-flux-products/SFN2_OCN.era5_shf.1x1.19860101-20201231.nc\ncreated by https://github.com/matt-long/sno-analysis/tree/50ea711 on 2022-02-15; created by https://github.com/matt-long/sno-analysis/tree/514728f on 2022-02-22" ;
# 		:NCO = "netCDF Operators version 4.9.5 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)" ;
# }
# format: netCDF-4
# ------------------------------
# ------------------------------
# Writing /glade/work/mclong/sno-analysis/sno-flux-products-camified/SFO2_FF.GCP-GridFED.v2021.3.0.9x1.25.19860101-20201231.nc
# netcdf SFO2_FF.GCP-GridFED.v2021.3.0.9x1.25.19860101-20201231 {
# dimensions:
# 	lat = 192 ;
# 	lon = 288 ;
# 	time = 12784 ;
# 	d2 = 2 ;
# 	n_time_components = 6 ;
# variables:
# 	double lat(lat) ;
# 	double lon(lon) ;
# 	double time_bnds(time, d2) ;
# 		time_bnds:_FillValue = 9.96920996838687e+36 ;
# 	float time_components(time, n_time_components) ;
# 		time_components:_FillValue = 9.96921e+36f ;
# 		time_components:long_name = "time components (year, month, day, hour, min, sec)" ;
# 		time_components:units = "none" ;
# 	int date(time) ;
# 		date:_FillValue = -2147483647 ;
# 		date:units = "YYYYMMDD" ;
# 		date:long_name = "Date" ;
# 	double time(time) ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1986-01-01" ;
# 		time:calendar = "gregorian" ;
# 	float area(lat, lon) ;
# 		area:_FillValue = 9.96921e+36f ;
# 		area:units = "m2" ;
# 	float SFO2_FF(time, lat, lon) ;
# 		SFO2_FF:_FillValue = 9.96921e+36f ;
# 		SFO2_FF:units = "molecules/cm2/s" ;
# 		SFO2_FF:long_name = "Total O2 surface flux from: OIL, GAS, COAL, BUNKER" ;
#
# // global attributes:
# 		:description = "Emissions of CO2 from fossil fuel sources on a 0.1 x 0.1 grid. EDGAR v4.3.2 annual emissions are scaled at the national level to GCP emissions and subsequently amalgamated in this dataset." ;
# 		:history = "Tue Feb 22 13:19:40 2022: ncks -O --fl_fmt=64bit /glade/scratch/mclong/sno-flux-products/SFO2_FF.GCP-GridFED.v2021.3.1x1.19860101-20201231.nc /glade/scratch/mclong/sno-flux-products/SFO2_FF.GCP-GridFED.v2021.3.1x1.19860101-20201231.nc\nCreated by Matt Jones (UEA) on 2022-02-02; aggegrated and regridded to 1x1 by Matt Long (NCAR); created by https://github.com/matt-long/sno-analysis/tree/bfdb4e7 on 2022-02-22; created by https://github.com/matt-long/sno-analysis/tree/514728f on 2022-02-22" ;
# 		:source = "https://zenodo.org/record/5956612" ;
# 		:NCO = "netCDF Operators version 4.9.5 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)" ;
# }
# format: netCDF-4
# ------------------------------
# ------------------------------
# Writing /glade/work/mclong/sno-analysis/sno-flux-products-camified/SFO2_OCN.cesm_fosi_smyle.0.9x1.25.19860101-20201231.nc
# netcdf SFO2_OCN.cesm_fosi_smyle.0.9x1.25.19860101-20201231 {
# dimensions:
# 	lat = 192 ;
# 	lon = 288 ;
# 	time = 12784 ;
# 	d2 = 2 ;
# 	n_time_components = 6 ;
# variables:
# 	double lat(lat) ;
# 	double lon(lon) ;
# 	double time_bnds(time, d2) ;
# 		time_bnds:_FillValue = 9.96920996838687e+36 ;
# 	float time_components(time, n_time_components) ;
# 		time_components:_FillValue = 9.96921e+36f ;
# 		time_components:long_name = "time components (year, month, day, hour, min, sec)" ;
# 		time_components:units = "none" ;
# 	int date(time) ;
# 		date:_FillValue = -2147483647 ;
# 		date:units = "YYYYMMDD" ;
# 		date:long_name = "Date" ;
# 	double time(time) ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1986-01-01" ;
# 		time:calendar = "gregorian" ;
# 	float area(lat, lon) ;
# 		area:_FillValue = 9.96921e+36f ;
# 		area:units = "m2" ;
# 	float SFO2_OCN(time, lat, lon) ;
# 		SFO2_OCN:_FillValue = 9.96921e+36f ;
# 		SFO2_OCN:long_name = "Dissolved Oxygen Surface Flux" ;
# 		SFO2_OCN:units = "molecules/cm2/s" ;
#
# // global attributes:
# 		:model_doi_url = "https://doi.org/10.5065/D67H1H0V" ;
# 		:source = "g.e22.GOMIPECOIAF_JRA-1p4-2018.TL319_g17.SMYLE.005" ;
# 		:note = "Leap day values are linearly interpolated from adjacent data" ;
# 		:history = "Tue Feb 22 13:19:48 2022: ncks -O --fl_fmt=64bit /glade/scratch/mclong/sno-flux-products/SFO2_OCN.cesm_fosi_smyle.1x1.19860101-20201231.nc /glade/scratch/mclong/sno-flux-products/SFO2_OCN.cesm_fosi_smyle.1x1.19860101-20201231.nc\ncreated by https://github.com/matt-long/sno-analysis/tree/3ae2e40 on 2022-02-15; created by https://github.com/matt-long/sno-analysis/tree/514728f on 2022-02-22" ;
# 		:NCO = "netCDF Operators version 4.9.5 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)" ;
# }
# format: netCDF-4
# ------------------------------
# ------------------------------
# Writing /glade/work/mclong/sno-analysis/sno-flux-products-camified/SFO2_OCN.gk2001_R2016.0.9x1.25.repeat_monclim.19860101-20201231.nc
# netcdf SFO2_OCN.gk2001_R2016.0.9x1.25.repeat_monclim.19860101-20201231 {
# dimensions:
# 	lat = 192 ;
# 	lon = 288 ;
# 	time = 12784 ;
# 	d2 = 2 ;
# 	n_time_components = 6 ;
# variables:
# 	double lat(lat) ;
# 	double lon(lon) ;
# 	double time_bnds(time, d2) ;
# 		time_bnds:_FillValue = 9.96920996838687e+36 ;
# 	float time_components(time, n_time_components) ;
# 		time_components:_FillValue = 9.96921e+36f ;
# 		time_components:long_name = "time components (year, month, day, hour, min, sec)" ;
# 		time_components:units = "none" ;
# 	int date(time) ;
# 		date:_FillValue = -2147483647 ;
# 		date:units = "YYYYMMDD" ;
# 		date:long_name = "Date" ;
# 	double time(time) ;
# 		time:bounds = "time_bnds" ;
# 		time:units = "days since 1986-01-01" ;
# 		time:calendar = "gregorian" ;
# 	float area(lat, lon) ;
# 		area:_FillValue = 9.96921e+36f ;
# 		area:units = "m2" ;
# 	float SFO2_OCN(time, lat, lon) ;
# 		SFO2_OCN:_FillValue = 9.96921e+36f ;
# 		SFO2_OCN:long_name = "GK01 O$_2$ seasonal flux w/ R2016 ann mean" ;
# 		SFO2_OCN:units = "molecules/cm2/s" ;
# 		SFO2_OCN:note = "GK2001 adjustments applied: scaleby = 0.82" ;
#
# // global attributes:
# 		:history = "Tue Feb 22 13:20:42 2022: ncks -O --fl_fmt=64bit /glade/scratch/mclong/sno-flux-products/SFO2_OCN.gk2001_R2016.1x1.repeat_monclim.19860101-20201231.nc /glade/scratch/mclong/sno-flux-products/SFO2_OCN.gk2001_R2016.1x1.repeat_monclim.19860101-20201231.nc\ncreated by https://github.com/matt-long/sno-analysis/tree/a0d9f9a on 2022-02-17; created by https://github.com/matt-long/sno-analysis/tree/514728f on 2022-02-22" ;
# 		:NCO = "netCDF Operators version 4.9.5 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)" ;
# }
# format: netCDF-4
# ------------------------------
# {'apo_jena': {'flux_file': '/glade/work/mclong/sno-analysis/sno-flux-products-camified/SFAPO_OCN.carboscope.apo99X_v2021.0.9x1.25.19860101-20201231.nc',
#   'constituent': 'O2',
#   'flux_variable': 'SFAPO_OCN'},
#  'co2_gridfed': {'flux_file': '/glade/work/mclong/sno-analysis/sno-flux-products-camified/SFCO2_FF.GCP-GridFED.v2021.3.0.9x1.25.19860101-20201231.nc',
#   'constituent': 'CO2',
#   'flux_variable': 'SFCO2_FF'},
#  'co2_oco2mip': {'flux_file': '/glade/work/mclong/sno-analysis/sno-flux-products-camified/SFCO2_FF.OCO2-MIP.v2020.1.0.9x1.25.19860101-20201231.nc',
#   'constituent': 'CO2',
#   'flux_variable': 'SFCO2_FF'},
#  'co2_cesm': {'flux_file': '/glade/work/mclong/sno-analysis/sno-flux-products-camified/SFCO2_OCN.cesm_fosi_smyle.0.9x1.25.19860101-20201231.nc',
#   'constituent': 'CO2',
#   'flux_variable': 'SFCO2_OCN'},
#  'co2_somffn': {'flux_file': '/glade/work/mclong/sno-analysis/sno-flux-products-camified/SFCO2_OCN.MPI-SOM-FFN.0.9x1.25.19860101-20201231.nc',
#   'constituent': 'CO2',
#   'flux_variable': 'SFCO2_OCN'},
#  'n2_cesm': {'flux_file': '/glade/work/mclong/sno-analysis/sno-flux-products-camified/SFN2_OCN.cesm_fosi_smyle.0.9x1.25.19860101-20201231.nc',
#   'constituent': 'N2',
#   'flux_variable': 'SFN2_OCN'},
#  'n2_era': {'flux_file': '/glade/work/mclong/sno-analysis/sno-flux-products-camified/SFN2_OCN.era5_shf.0.9x1.25.19860101-20201231.nc',
#   'constituent': 'N2',
#   'flux_variable': 'SFN2_OCN'},
#  'o2_gridfed': {'flux_file': '/glade/work/mclong/sno-analysis/sno-flux-products-camified/SFO2_FF.GCP-GridFED.v2021.3.0.9x1.25.19860101-20201231.nc',
#   'constituent': 'O2',
#   'flux_variable': 'SFO2_FF'},
#  'o2_cesm': {'flux_file': '/glade/work/mclong/sno-analysis/sno-flux-products-camified/SFO2_OCN.cesm_fosi_smyle.0.9x1.25.19860101-20201231.nc',
#   'constituent': 'O2',
#   'flux_variable': 'SFO2_OCN'},
#  'o2_gk01r16': {'flux_file': '/glade/work/mclong/sno-analysis/sno-flux-products-camified/SFO2_OCN.gk2001_R2016.0.9x1.25.repeat_monclim.19860101-20201231.nc',
#   'constituent': 'O2',
#   'flux_variable': 'SFO2_OCN'}}

# %%
with open('srf-emis-apo-forward.yml', 'w') as fid:
    yaml.dump(srf_emis_files_camified, fid)
